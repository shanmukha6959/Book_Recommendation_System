# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataset:
#
# https://www.kaggle.com/datasets/rxsraghavagrawal/book-recommender-system

# %% [markdown]
# # Reading the Data

# %%
book= pd.read_csv("data/BX-Book-Ratings.csv", sep = ';', on_bad_lines='skip', encoding='ISO-8859–1')
book_isbn=pd.read_csv("data/BX-Books.csv", sep = ';', on_bad_lines='skip', encoding='ISO-8859–1')
# Out:
# /Users/kishore/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
book.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
book_details=book_isbn[["ISBN","Book-Title","Book-Author","Year-Of-Publication"]]
book_details.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication
# 0    Mark P. O. Morford                2002
# 1  Richard Bruce Wright                2001
# 2          Carlo D'Este                1991
# 3      Gina Bari Kolata                1999
# 4       E. J. W. Barber                1999

# %%
Merge_data = book.merge(book_details, on="ISBN", how = 'inner')

# %%
Merge_data.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication
# 0                2002
# 1                2002
# 2                2002
# 3                2002
# 4                2002

# %% [markdown]
# # Data Visualization and Preprocessing

# %%
import matplotlib.pyplot as plt
# Rating Count
plt.rc("font", size=12)
Merge_data["Book-Rating"].value_counts(sort=True).plot(kind='bar')
plt.title('Rating Distribution\n')
plt.xlabel('Rating')
plt.ylabel('Count of the Ratings')
plt.show()

# %%
Merge_data.shape
# Out:
# (1031136, 6)

# %%
# Counting the number of rating in each book
rating_total_count = pd.DataFrame(Merge_data.groupby('ISBN')['Book-Rating'].count())
rating_total_count.sort_values('Book-Rating', ascending=False).head(10)
# Out:
#             Book-Rating
# ISBN
# 0971880107         2502
# 0316666343         1295
# 0385504209          883
# 0060928336          732
# 0312195516          723
# 044023722X          647
# 0142001740          615
# 067976402X          614
# 0671027360          586
# 0446672211          585

# %%
# Counting the number of rating given by each user
user_total_count = pd.DataFrame(Merge_data.groupby('User-ID')['Book-Rating'].count())
user_total_count.sort_values('Book-Rating', ascending=False).head(10)
# Out:
#          Book-Rating
# User-ID
# 11676          11144
# 198711          6456
# 153662          5814
# 98391           5779
# 35859           5646
# 212898          4289
# 278418          3996
# 76352           3329
# 110973          2971
# 235105          2943

# %%
# We need to make sure that the book has enough reviews from users and the users has also given enough reviews.

#Getting users who had given more than 100 ratings 
user_count = Merge_data['User-ID'].value_counts()
Merge_data = Merge_data[Merge_data['User-ID'].isin(user_count[user_count >= 100].index)]

#Getting books which have more than 100 ratings by the users
book_count = Merge_data['Book-Rating'].value_counts()
Merge_data = Merge_data[Merge_data['Book-Rating'].isin(book_count[book_count >= 100].index)]

# %%
Merge_data.shape
# Out:
# (592996, 6)

# %%
data=Merge_data[['User-ID','ISBN','Book-Rating','Book-Title']]
data.rename(columns = {'User-ID':'userid','Book-Rating':'bookrating','Book-Title':'booktitle'}, inplace = True)
# Out:
# /Users/kishore/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data.reset_index()
# Out:
#           index  userid        ISBN  bookrating  \
# 0             2    6543  034545104X           0
# 1             4   10314  034545104X           9
# 2             5   23768  034545104X           0
# 3             7   28523  034545104X           0
# 4            14   77480  034545104X           8
# ...         ...     ...         ...         ...
# 592991  1031115  276680  0812881311           0
# 592992  1031116  276680  0865055041           0
# 592993  1031117  276680  086505505X           0
# 592994  1031118  276680  1564407284           0
# 592995  1031119  276680  1582343594           0
#
#                                                 booktitle
# 0                                    Flesh Tones: A Novel
# 1                                    Flesh Tones: A Novel
# 2                                    Flesh Tones: A Novel
# 3                                    Flesh Tones: A Novel
# 4                                    Flesh Tones: A Novel
# ...                                                   ...
# 592991                                    Streets of Gold
# 592992         Kitchen (Historic Communities (Paperback))
# 592993     Home Crafts (Historic Communities (Paperback))
# 592994  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 592995                 City of Masks : A Cree Black Novel
#
# [592996 rows x 5 columns]

# %% [markdown]
# # Collaborative Filtering using k Nearest Neighbour

# %%
data1 = data.merge(rating_total_count, left_on = 'ISBN', right_on = 'ISBN', how = 'left')
data1.rename(columns = {'Book-Rating':'totalratings'}, inplace = True)
data1.head()
# Out:
#    userid        ISBN  bookrating             booktitle  totalratings
# 0    6543  034545104X           0  Flesh Tones: A Novel            60
# 1   10314  034545104X           9  Flesh Tones: A Novel            60
# 2   23768  034545104X           0  Flesh Tones: A Novel            60
# 3   28523  034545104X           0  Flesh Tones: A Novel            60
# 4   77480  034545104X           8  Flesh Tones: A Novel            60

# %%
data1.shape
# Out:
# (592996, 5)

# %%
threshold = 50
data1 = data1.query('totalratings >= @threshold')
data1.head()
# Out:
#    userid        ISBN  bookrating             booktitle  totalratings
# 0    6543  034545104X           0  Flesh Tones: A Novel            60
# 1   10314  034545104X           9  Flesh Tones: A Novel            60
# 2   23768  034545104X           0  Flesh Tones: A Novel            60
# 3   28523  034545104X           0  Flesh Tones: A Novel            60
# 4   77480  034545104X           8  Flesh Tones: A Novel            60

# %%
data1.shape
# Out:
# (116864, 5)

# %%
#Cosine Similarity

from scipy.sparse import csr_matrix
data1 = data1.drop_duplicates(['userid', 'booktitle'])
data_pivot = data1.pivot(index = 'booktitle', columns = 'userid', values = 'bookrating').fillna(0)
data1_mat = csr_matrix(data_pivot.values)

# kNN Model
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(data1_mat)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
#Testing
query_index = np.random.choice(data_pivot.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(data_pivot.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 1835

# %%
data_pivot.index[query_index]
# Out:
# "Tom Clancy's Op-Center: Games of State (Tom Clancy's Op Center (Paperback))"

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(data_pivot.index[query_index]))
    else:
        print('{0}: {1}'.format(i, data_pivot.index[indices.flatten()[i]]))
# Out:
# Recommendations for Tom Clancy's Op-Center: Games of State (Tom Clancy's Op Center (Paperback)):
#
# 1: Night Moves (Tom Clancy's Net Force, No. 3)
# 2: Ruthless.Com (Tom Clancy's Power Plays (Paperback))
# 3: Politika (Tom Clancy's Power Plays (Paperback))
# 4: Paradise Lost
# 5: Net Force

# %%
#Saving model
import pickle
pickle.dump(model_knn,open('model/model_recom.pkl','wb'))

# %% [markdown]
# # Deployment Using Flask Application

# %%
# !pip install flask-ngrok2
# Out:
# Requirement already satisfied: flask-ngrok2 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: requests in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask-ngrok2) (2.26.0)
# Requirement already satisfied: Flask>=0.8 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask-ngrok2) (0.12.2)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-ngrok2) (2.0.1)
# Requirement already satisfied: click>=2.0 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-ngrok2) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-ngrok2) (2.0.2)
# Requirement already satisfied: Jinja2>=2.4 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-ngrok2) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.4->Flask>=0.8->flask-ngrok2) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from requests->flask-ngrok2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from requests->flask-ngrok2) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from requests->flask-ngrok2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from requests->flask-ngrok2) (3.2)

# %%
# !pip install flask==0.12.2
# Out:
# Requirement already satisfied: flask==0.12.2 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: itsdangerous>=0.21 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask==0.12.2) (2.0.1)
# Requirement already satisfied: click>=2.0 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask==0.12.2) (8.0.3)
# Requirement already satisfied: Jinja2>=2.4 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask==0.12.2) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.7 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from flask==0.12.2) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/kishore/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.4->flask==0.12.2) (1.1.1)

# %%
#Flask Application
from flask import Flask, request, jsonify, render_template
from flask_ngrok2 import run_with_ngrok

# %%
books_list=list(data_pivot.index)

# %%
 with open("data/book_list.txt", "wb") as fp:
   pickle.dump(books_list, fp)

# %%
books_list
# Out:
# ['16 Lighthouse Road',
#  '1984',
#  '1st to Die: A Novel',
#  '2010: Odyssey Two',
#  '204 Rosewood Lane',
#  '24 Hours',
#  '2nd Chance',
#  '3rd Degree',
#  '4 Blondes',
#  '50 Simple Things You Can Do to Save the Earth',
#  '84 Charing Cross Road',
#  'A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))',
#  'A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash',
#  'A Bend in the Road',
#  'A Case of Need',
#  'A Child Called \\It\\": One Child\'s Courage to Survive"',
#  'A Civil Action',
#  'A Clockwork Orange (Norton Paperback Fiction)',
#  'A Cold Heart (Alex Delaware Novels (Paperback))',
#  'A Cold Heart: An Alex Delaware Novel',
#  'A Confederacy of Dunces',
#  'A Confederacy of Dunces (Evergreen Book)',
#  'A Cry In The Night',
#  "A Cup of Tea (Ballantine Reader's Circle)",
#  'A Dangerous Fortune',
#  'A Darkness More Than Night',
#  'A Day Late and a Dollar Short',
#  'A Fine Balance',
#  'A Game of Thrones (A Song of Ice and Fire, Book 1)',
#  'A Girl Named Zippy: Growing Up Small in Mooreland Indiana (Today Show Book Club #3)',
#  'A Great Deliverance',
#  'A Heartbreaking Work Of Staggering Genius : A Memoir Based on a True Story',
#  'A Heartbreaking Work of Staggering Genius',
#  'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))',
#  'A Kiss of Shadows (Meredith Gentry Novels (Paperback))',
#  'A Lesson Before Dying (Vintage Contemporaries (Paperback))',
#  'A Light in the Window (The Mitford Years)',
#  "A Maiden's Grave",
#  'A Man Named Dave: A Story of Triumph and Forgiveness',
#  'A Man in Full',
#  'A Map of the World',
#  'A Monk Swimming : A Memoir',
#  'A New Song (Mitford Years (Paperback))',
#  'A Night to Remember',
#  'A Painted House',
#  'A Passage to India',
#  'A Patchwork Planet',
#  "A Patchwork Planet (Ballantine Reader's Circle)",
#  'A Perfect Stranger',
#  'A Pirate Looks at Fifty',
#  'A Place Called Freedom',
#  'A Place of Execution',
#  'A Prayer for Owen Meany',
#  'A RIVER RUNS THROUGH IT AND OTHER STORIES : AND OTHER STORIES',
#  "A Rose For Her Grave &amp; Other True Cases (Ann Rule's Crime Files)",
#  'A Separate Peace',
#  'A Short Guide to a Happy Life',
#  'A Simple Plan',
#  'A Son of the Circus',
#  'A Spell for Chameleon (Xanth Novels (Paperback))',
#  'A Swiftly Tilting Planet',
#  'A Theory of Relativity',
#  'A Thief of Time (Joe Leaphorn/Jim Chee Novels)',
#  'A Thin Dark Line (Mysteries &amp; Horror)',
#  "A Thousand Acres (Ballantine Reader's Circle)",
#  'A Time to Kill',
#  'A Traitor to Memory',
#  'A Tree Grows in Brooklyn',
#  "A Virtuous Woman (Oprah's Book Club (Paperback))",
#  'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#  'A Walk in the Woods: Rediscovering America on the Appalachian Trail (Official Guides to the Appalachian Trail)',
#  'A Walk to Remember',
#  'A Widow for One Year',
#  'A Widow for One Year : A Novel',
#  'A Wind in the Door',
#  'A Wizard of Earthsea (Earthsea Trilogy, Book 1)',
#  'A Wrinkle In Time',
#  'A Wrinkle in Time',
#  'A Year in Provence',
#  'A Yellow Raft in Blue Water',
#  'AGE OF INNOCENCE (MOVIE TIE-IN)',
#  "ANGELA'S ASHES",
#  'Abduction',
#  'About Face',
#  'About a Boy',
#  'About a Boy (Movie Tie-In)',
#  'Absolute Power',
#  'Acceptable Risk',
#  'Accident',
#  'Accidental Tourist',
#  'Accordion Crimes',
#  'Acts of Malice',
#  "Acts of War (Tom Clancy's Op Center (Paperback))",
#  'Affinity',
#  'After All These Years',
#  'After the Fire',
#  "Ahab's Wife: Or, The Star-Gazer: A Novel",
#  'Airframe',
#  'Alaska',
#  'Alias Grace',
#  'Alias Grace : A Novel',
#  'Alive : The Story of the Andes Survivors (Avon Nonfiction)',
#  'All Around the Town',
#  'All He Ever Wanted',
#  'All I Need to Know I Learned from My Cat',
#  'All I Really Need to Know',
#  'All Quiet on the Western Front',
#  'All That Glitters (Landry)',
#  'All That Remains (Kay Scarpetta Mysteries (Paperback))',
#  'All Through the Night (Holiday Classics)',
#  "All over but the Shoutin'",
#  'All the Pretty Horses (The Border Trilogy, Vol 1)',
#  'Along Came a Spider (Alex Cross Novels)',
#  'American Gods',
#  'American Gods: A Novel',
#  'American Psycho (Vintage Contemporaries)',
#  'Amsterdam : A Novel',
#  'Amy and Isabelle : A novel',
#  'An Accidental Woman',
#  'An Instance of the Fingerpost',
#  'And Ladies of the Club',
#  'And Then There Were None',
#  'And Then There Were None : A Novel',
#  'And Then You Die',
#  'Angel Falls',
#  "Angela's Ashes (MMP) : A Memoir",
#  "Angela's Ashes: A Memoir",
#  'Angelas Ashes',
#  'Angels',
#  'Angels &amp; Demons',
#  'Angels Flight (Detective Harry Bosch Mysteries)',
#  'Angle of Repose (Contemporary American Fiction)',
#  'Angry Housewives Eating Bon Bons',
#  "Angry Housewives Eating Bon Bons (Ballantine Reader's Circle)",
#  'Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson',
#  "Anil's Ghost (Vintage International)",
#  'Animal Dreams',
#  'Animal Farm',
#  'Animal Husbandry',
#  'Anne Frank: The Diary of a Young Girl',
#  'Anne of Avonlea (Anne of Green Gables Novels (Paperback))',
#  'Anne of Green Gables (Anne of Green Gables Novels (Paperback))',
#  'Anne of Ingleside (Anne of Green Gables Novels (Paperback))',
#  'Anne of Windy Poplars (Anne of Green Gables Novels (Paperback))',
#  'Anne of the Island',
#  "Anne's House of Dreams",
#  'Apocalipstick',
#  'Apollo 13 : Lost Moon',
#  'Apollyon: The Destroyer Is Unleashed (Left Behind No. 5)',
#  "Are You There God?  It's Me, Margaret",
#  'Artemis Fowl (Artemis Fowl, Book 1)',
#  'As Nature Made Him: The Boy Who Was Raised As a Girl',
#  'As the Crow Flies',
#  'Ashes to Ashes',
#  'Asking for Trouble: A Novel',
#  'Assassins: Assignment: Jerusalem, Target: Antichrist (Left Behind No. 6)',
#  'At Home in Mitford (The Mitford Years)',
#  'At Risk',
#  'Atlantis Found',
#  'Atlas Shrugged',
#  'Atonement : A Novel',
#  'Atonement: A Novel',
#  'Awakening',
#  'B Is for Burglar (Kinsey Millhone Mysteries (Paperback))',
#  'BAG OF BONES : A NOVEL',
#  'BODY FARM',
#  'Babyville',
#  "Bachelor Brothers' Bed &amp; Breakfast",
#  'Back Roads',
#  "Back When We Were Grownups : A Novel (Ballantine Reader's Circle)",
#  'Back When We Were Grownups: A Novel',
#  'Bad Boy',
#  'Bad Heir Day',
#  'Bad Love (Alex Delaware Novels (Paperback))',
#  'Bag of Bones',
#  'Balzac and the Little Chinese Seamstress',
#  'Balzac and the Little Chinese Seamstress : A Novel',
#  'Barrel Fever : Stories and Essays (Barrel Fever)',
#  'Basket Case',
#  'Bastard Out of Carolina',
#  'Battlefield Earth: A Saga of the Year 3000',
#  'Beach House',
#  'Beach Music',
#  'Bearing an Hourglass (Incarnations of Immortality (Paperback))',
#  'Bee Season: A Novel',
#  'Before I Say Good-Bye',
#  'Before I Say Good-Bye : A Novel',
#  "Before Women Had Wings (Ballantine Reader's Circle)",
#  'Behind the Scenes at the Museum',
#  'Behind the Scenes at the Museum : A Novel',
#  'Bel Canto',
#  'Bel Canto: A Novel',
#  'Belinda',
#  'Bell Jar',
#  'Beloved',
#  'Beloved (Plume Contemporary Fiction)',
#  'Betrayal in Death',
#  'Between Friends',
#  'Beyond Eden',
#  "Big Cherry Holler: A Big Stone Gap Novel (Ballantine Reader's Circle)",
#  'Big Fish',
#  'Big Stone Gap',
#  "Big Stone Gap: A Novel (Ballantine Reader's Circle)",
#  'Big Trouble',
#  'Billy',
#  'Billy Straight : A Novel',
#  "Bio-Strike (Tom Clancy's Power Plays (Paperback))",
#  'Birds of Prey: A Novel of Suspense',
#  'Birthright',
#  'Bitter Harvest',
#  'Bitter Sweet',
#  'Bittersweet',
#  'Black Friday',
#  'Black Hawk Down (Movie Tie-in)',
#  'Black House',
#  'Black Lightning',
#  'Black Notice',
#  'Black and Blue',
#  'Black and Blue : A Novel',
#  'Blackberry Wine',
#  'Blackbird: A Childhood Lost and Found',
#  'Bleachers',
#  'Bless Me, Ultima',
#  'Blessings',
#  'Blessings : A Novel',
#  'Blindness (Harvest Book)',
#  'Blindsight',
#  'Blindsighted',
#  'Blood Lure',
#  'Blood Orchid',
#  'Blood Shot (V.I. Warshawski Novels (Paperback))',
#  'Blood Work',
#  'Blood and Gold (Rice, Anne, Vampire Chronicles.)',
#  'Bloodstream',
#  'Bloodsucking Fiends: A Love Story',
#  'Bloody Bones (Anita Blake Vampire Hunter (Paperback))',
#  'Blow Fly: A Scarpetta Novel',
#  'Blue Diary',
#  'Blue Highways a Journey Into America',
#  'Blue Shoe',
#  'Body of Evidence',
#  'Body of Evidence (Kay Scarpetta Mysteries (Paperback))',
#  'Body of Lies',
#  'Book Club',
#  'Bookends : A Novel',
#  'Border Music',
#  'Born in Fire',
#  'Born in Ice',
#  'Born in Shame',
#  "Boy's Life",
#  'Brave New World',
#  'Brazen Virtue',
#  'Breach of Promise',
#  'Breakfast of Champions',
#  "Breaking Point (Tom Clancy's Net Force, No. 4)",
#  'Breath, Eyes, Memory',
#  'Breathing Lessons',
#  'Bridge to Terabithia',
#  'Bridget Jones : The Edge of Reason',
#  "Bridget Jones's Diary",
#  'Bridget Jones: The Edge of Reason',
#  'Burn Factor',
#  'Burn Marks (V.I. Warshawski Novels (Paperback))',
#  'Butterfly (Orphans)',
#  'By the Light of the Moon',
#  'Bygones',
#  'C Is for Corpse (Kinsey Millhone Mysteries (Paperback))',
#  "CAT'S EYE",
#  'CHOCOLATE FOR A WOMANS SOUL : 77 STORIES TO FEED YOUR SPIRIT AND WARM YOUR HEART (Chocolate)',
#  'CRY IN THE NIGHT, A',
#  'Cabin',
#  'Call of the Wild',
#  'Can You Keep a Secret?',
#  'Candide (Penguin Classics)',
#  'Cane River',
#  "Cane River (Oprah's Book Club (Paperback))",
#  'Caribbean',
#  'Carnal Innocence',
#  'Carolina Moon',
#  'Cat &amp; Mouse (Alex Cross Novels)',
#  'Cat and Mouse',
#  'Catch 22',
#  'Catch Me If You Can: The True Story of a Real Fake',
#  'Catering to Nobody',
#  'Catherine, Called Birdy (Trophy Newbery)',
#  'Cause Celeb',
#  'Cause of Death',
#  'Certain Prey',
#  'Changes',
#  'Chapterhouse Dune (Dune Chronicles, Book 6)',
#  "Charlotte's Web",
#  "Charlotte's Web (Trophy Newbery)",
#  'Charming Billy',
#  'Charms for Easy Life',
#  'Chasing the Dime',
#  'Cheet (Plume Books)',
#  'Chesapeake Blue (Quinn Brothers (Hardcover))',
#  'Chicken Soup for the College Soul : Inspiring and Humorous Stories for College Students (Chicken Soup for the Soul)',
#  "Chicken Soup for the Mother's Soul (Chicken Soup for the Soul Series (Paper))",
#  "Chicken Soup for the Pet Lover's Soul (Chicken Soup for the Soul)",
#  'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#  'Chicken Soup for the Teenage Soul (Chicken Soup for the Soul)',
#  'Chicken Soup for the Teenage Soul II (Chicken Soup for the Soul Series)',
#  "Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))",
#  'Child of My Heart',
#  "Childhood's End",
#  'Children of Dune (Dune Chronicles, Book 3)',
#  'Chocolat',
#  'Choke',
#  'Chopping Spree',
#  'Chosen Prey',
#  'Christine',
#  'Christmas Box (Christmas Box Trilogy)',
#  'Christy',
#  'Chromosome 6',
#  'Circle of Friends',
#  'Circle of Three: A Novel',
#  'Circus of the Damned (Anita Blake Vampire Hunter (Paperback))',
#  'City of Bones',
#  'City of Golden Shadow (Otherland, Volume 1)',
#  'City of Light',
#  'Clear and Present Danger',
#  'Clear and Present Danger (Jack Ryan Novels)',
#  'Cloud Nine',
#  'Club Dead (Southern Vampire Mysteries)',
#  'Coast Road: A Novel',
#  'Code to Zero',
#  'Cold Blooded',
#  'Cold Fire',
#  'Cold Mountain',
#  'Cold Mountain : A Novel',
#  'Cold Paradise (Stone Barrington Novels (Paperback))',
#  'Cold Sassy Tree',
#  'Colony',
#  'Coming Home',
#  'Communion : A True Story',
#  'Confessions of a Shopaholic',
#  'Confessions of a Shopaholic (Summer Display Opportunity)',
#  'Confessions of a Sociopathic Social Climber : The Katya Livingston Chronicles (Katya Livingston Chronicles (Hardcover))',
#  'Confessions of an Ugly Stepsister : A Novel',
#  'Congo',
#  'Considering Kate (The Stanislaskis) (Silhouette Special Edition)',
#  'Contact',
#  'Contagion',
#  'Conversations with God : An Uncommon Dialogue (Book 1)',
#  'Coraline',
#  "Cordina's Crown Jewel",
#  "Corelli's Mandolin : A Novel",
#  'Couplehood',
#  'Courting Trouble',
#  'Coyote Waits (Joe Leaphorn/Jim Chee Novels)',
#  'Cradle and All',
#  'Crazy for You',
#  'Creature',
#  'Creed for the Third Millennium',
#  'Critical Judgment',
#  'Critical Mass',
#  'Crocodile on the Sandbank',
#  'Crossings',
#  'Crow Lake (Today Show Book Club #7)',
#  'Cruel &amp; Unusual (Kay Scarpetta Mysteries (Paperback))',
#  'Cry Wolf',
#  'Cry to Heaven',
#  "Cry, the Beloved Country (Oprah's Book Club)",
#  'Cryptonomicon',
#  'Cujo',
#  "Cybernation (Tom Clancy's Net Force, No. 6)",
#  'D Is for Deadbeat (Kinsey Millhone Mysteries (Paperback))',
#  'DEAD BY SUNSET : DEAD BY SUNSET',
#  'Daddy',
#  "Daddy's Little Girl",
#  'Daisy Fay and the Miracle Man',
#  'Dance Hall of the Dead (Joe Leaphorn Novels)',
#  'Dance upon the Air (Three Sisters Island Trilogy)',
#  'Dances With Wolves',
#  'Dandelion Wine (Grand Master Editions)',
#  'Dangerous',
#  'Daring to Dream',
#  'Dark Lady',
#  'Dark Paradise',
#  'Dark Rivers of the Heart',
#  'Dark Water (Mira Romantic Suspense)',
#  'Darkest Hour (Cutler)',
#  'Darkfall',
#  'Darkness',
#  "Darwin's Radio",
#  'Das Parfum: Die Geschichte Eines Morders',
#  'Dating Without Novocaine (Red Dress Ink)',
#  'Daughter of Fortune',
#  "Daughter of Fortune : A Novel (Oprah's Book Club (Hardcover))",
#  'Daughter of Fortune: A Novel',
#  'Dawn (Cutler)',
#  'Dead Aim',
#  'Dead Famous',
#  'Dead Run',
#  'Dead Sleep',
#  'Dead Until Dark (Southern Vampire Mysteries)',
#  'Deadly Decisions',
#  'Death du Jour',
#  'Death in Holy Orders : An Adam Dalgliesh Mystery',
#  'Death of A Salesman',
#  'Debt of Honor',
#  'Debt of Honor (Jack Ryan Novels)',
#  'Deception Point',
#  'Deception on His Mind',
#  'Deck the Halls (Holiday Classics)',
#  'Deep South',
#  'Degree of Guilt',
#  'Deja Dead',
#  'Demon Seed',
#  'Der Vorleser',
#  'Desecration: Antichrist Takes the Throne (Left Behind No. 9)',
#  'Desperation',
#  'Devices and Desires',
#  "Devil's Waltz (Alex Delaware Novels (Paperback))",
#  'Diary of a Mad Bride (Summer Display Opportunity)',
#  'Different Seasons',
#  'Different Seasons (Signet)',
#  'Digital Fortress : A Thriller',
#  'Disclosure',
#  'Disobedience: A Novel',
#  'Distant Shores',
#  'Divine Secrets of the Ya-Ya Sisterhood : A Novel',
#  'Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#  'Dog Handling',
#  'Doing Good',
#  'Dolores Claiborne',
#  "Don't Let's Go to the Dogs Tonight : An African Childhood",
#  "Don't Stand Too Close to a Naked Man",
#  "Don't Sweat the Small Stuff and It's All Small Stuff : Simple Ways to Keep the Little Things from Taking Over Your Life (Don't Sweat the Small Stuff Series)",
#  'Doomsday Book',
#  "Dr. Atkins' New Diet Revolution",
#  'Dr. Death (Alex Delaware Novels (Paperback))',
#  'Dr. Death: A Novel',
#  'Dracula (Signet Classics (Paperback))',
#  'Dragon Tears',
#  'Dragonflight (Dragonriders of Pern Trilogy (Paperback))',
#  'Dragonfly in Amber',
#  'Dragons of Autumn Twilight (Dragonlance Chronicles, Vol 1)',
#  'Dragonsdawn',
#  'Dream Country',
#  'Dreamcatcher',
#  'Drowning Ruth',
#  "Drowning Ruth (Oprah's Book Club)",
#  'Drums of Autumn',
#  "Dude, Where's My Country?",
#  'Dune',
#  'Dune (Remembering Tomorrow)',
#  'Dune Messiah (Dune Chronicles, Book 2)',
#  'Dust to Dust',
#  'Dying for Chocolate (Culinary Mysteries (Paperback))',
#  'E Is for Evidence: A Kinsey Millhone Mystery (Kinsey Millhone Mysteries (Paperback))',
#  'EVERYTHING SHE EVER WANTED',
#  "East of Eden (Oprah's Book Club)",
#  'East of the Mountains',
#  'East of the Mountains (Vintage Contemporaries (Paperback))',
#  'Easy Prey',
#  'Eaters of the Dead',
#  'Eats, Shoots &amp; Leaves: The Zero Tolerance Approach to Punctuation',
#  'Echoes',
#  'Eden Close',
#  "Einstein's Dreams",
#  'Eleventh Hour: An FBI Thriller (FBI Thriller (Jove Paperback))',
#  'Elfstones of Shannara',
#  'Ella Minnow Pea: A Novel in Letters',
#  'Ellen Foster',
#  'Embraced by the Light',
#  'Empire Falls',
#  'Empty Promises',
#  'Endangered Species (Anna Pigeon Mysteries (Paperback))',
#  "Ender's Game (Ender Wiggins Saga (Paperback))",
#  "Ender's Shadow",
#  'Enemy Women: A Novel',
#  'Engaging Men (Red Dress Ink (Paperback))',
#  'Engaging The Enemy',
#  'Envy',
#  'Eragon (Inheritance, Book 1)',
#  'Escape the Night',
#  'Eva Luna',
#  'Evening Class',
#  'Every Breath You Take : A True Story of Obsession, Revenge, and Murder',
#  'Everything Is Illuminated : A Novel',
#  "Everything's Eventual : 14 Dark Tales",
#  'Exclusive',
#  'Executive Orders (Jack Ryan Novels)',
#  'Extreme Measures',
#  'Eyes of Prey',
#  'Eyes of a Child',
#  'Eyes of the Dragon',
#  'F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))',
#  'FIRST WIVES CLUB',
#  'FLOOD TIDE',
#  'FOREVER : A Novel of Good and Evil, Love and Hope',
#  'FORREST GUMP (Movie Tie in)',
#  "FROM POTTER'S FIELD",
#  'Face the Fire (Three Sisters Island Trilogy)',
#  'Fahrenheit 451',
#  'Faking It',
#  'Fall On Your Knees (Oprah #45)',
#  'Fallen Hearts',
#  'Falling Angels',
#  'Falling Leaves Brit Edition',
#  'Falling Leaves: The True Story of an Unwanted Chinese Daughter',
#  'False Memory',
#  'False Pretenses',
#  'Family Album',
#  'Family: The Ties That Bind and Gag',
#  'Farewell To Arms',
#  'Farewell to Manzanar: A True Story of Japanese American Experience During and  After the World War II Internment',
#  'Farm Fatale: A Comedy of Country Manors',
#  'Fast Food Nation: The Dark Side of the All-American Meal',
#  'Fast Women',
#  'Fat Tuesday',
#  'Fatal Cure',
#  'Fatal Voyage',
#  'Fatherhood',
#  'Fear Nothing',
#  'Fear and Loathing in Las Vegas : A Savage Journey to the Heart of the American Dream',
#  'Feast of All Saints',
#  'Female Intelligence',
#  'Fight Club',
#  'Final Target',
#  'Find Me',
#  'Finding Moon',
#  'Finding the Dream',
#  'Fine Things',
#  'Fingersmith',
#  'Fire Ice: A Novel from the Numa Files (Kurt Austin Adventures (Paperback))',
#  'Firefly Beach',
#  'Firefly Summer',
#  'Firestarter',
#  'Firestorm (Anna Pigeon Mysteries (Paperback))',
#  'Fishbowl (Red Dress Ink (Paperback))',
#  'Five Days in Paris',
#  'Five Quarters of the Orange',
#  'Flesh Tones: A Novel',
#  'Flesh and Blood',
#  'Flowers In The Attic (Dollanganger)',
#  'Flowers for Algernon (Bantam Classic)',
#  'Fluke : Or, I Know Why the Winged Whale Sings',
#  'Follow the Stars Home',
#  'For Better, for Worse: A Novel',
#  'Forbidden Fruit',
#  'Forever... : A Novel of Good and Evil, Love and Hope',
#  "Fortune's Hand",
#  "Fortune's Rocks : A Novel",
#  "Fortune's Rocks: A Novel",
#  "Foucault's Pendulum",
#  'Four Blind Mice',
#  'Four Blondes',
#  'Four Past Midnight',
#  'Four To Score (A Stephanie Plum Novel)',
#  'Fourplay: A Novel',
#  'Fourth Procedure',
#  'Frankenstein (Changing Our World)',
#  'Franny and Zooey',
#  'Free',
#  'French Silk',
#  'Friday',
#  'Fried Green Tomatoes at the Whistle Stop Cafe',
#  "From Potter's Field",
#  'From a Buick 8',
#  'From a Buick 8 : A Novel',
#  'From the Corner of His Eye',
#  "Full Blast (Janet Evanovich's Full Series)",
#  "Full House (Janet Evanovich's Full Series)",
#  "Full Speed (Janet Evanovich's Full Series)",
#  "Full Tilt (Janet Evanovich's Full Series)",
#  'G Is for Gumshoe (Kinsey Millhone Mysteries (Paperback))',
#  'GARDEN OF SHADOWS (Dollanger Saga (Paperback))',
#  'Galapagos',
#  "Galileo's Daughter: A Historical Memoir of Science, Faith, and Love",
#  'Gap Creek: A Novel',
#  'Gap Creek: The Story Of A Marriage',
#  'Gap Creek: The Story of a Marriage',
#  'Gates of Paradise',
#  'Geek Love',
#  'Generation X: Tales for an Accelerated Culture',
#  'Genuine Lies',
#  "Gerald's Game",
#  'Get Shorty',
#  'Getting Over It',
#  'Getting Rid Of Bradley',
#  'Ghost Moon',
#  'Gift from the Sea',
#  'Girl With a Pearl Earring',
#  'Girl in Hyacinth Blue',
#  'Girl with a Pearl Earring',
#  'Girl, Interrupted',
#  'Girlfriends: Invisible Bonds, Enduring Ties',
#  'Girls Night',
#  'Glory in Death',
#  'Go Ask Alice',
#  'God Save the Sweet Potato Queens',
#  'Going Home',
#  'Gone But Not Forgotten',
#  'Gone For Good',
#  'Gone for Good',
#  'Gone with the Wind',
#  'Good Harbor: A Novel',
#  'Good Omens',
#  'Good in Bed',
#  'Gorky Park',
#  'Grand Avenue',
#  'Granny Dan',
#  'Grave Secrets',
#  'Grave Secrets (Temperance Brennan Novel (Hardcover))',
#  'Gravity : A Novel of Medical Suspense',
#  'Grendel',
#  'Griffin &amp; Sabine: An Extraordinary Correspondence',
#  'Ground Zero and Beyond',
#  'Guardian',
#  'Guardian Angel',
#  'Guilty Pleasures (Anita Blake Vampire Hunter (Paperback))',
#  'Guilty as Sin',
#  'Guns, Germs, and Steel: The Fates of Human Societies',
#  'H Is for Homicide (Kinsey Millhone Mysteries (Paperback))',
#  'Half Asleep in Frog Pajamas',
#  "Hanna's Daughters (Ballantine Reader's Circle)",
#  'Hannibal',
#  'Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#  'Hard Time (V.I. Warshawski Novels (Paperback))',
#  'Harmful Intent',
#  'Harry Potter and the Chamber of Secrets (Book 2)',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  'Harry Potter and the Order of the Phoenix (Book 5)',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#  'Harvest',
#  'Haunted',
#  "Having Our Say : The Delany Sisters' First 100 Years",
#  "He Sees You When You're Sleeping : A Novel",
#  'Heart Song (Logan)',
#  'Heart of the Sea (Irish Trilogy)',
#  'Heartbeat',
#  'Heartbreaker',
#  'Hearts In Atlantis',
#  'Hearts In Atlantis : New Fiction',
#  'Hearts in Atlantis',
#  'Heaven and Earth (Three Sisters Island Trilogy)',
#  'Heir to the Empire (Star Wars: The Thrawn Trilogy, Vol. 1)',
#  'Hemlock Bay',
#  'Here on Earth',
#  "Here on Earth (Oprah's Book Club)",
#  "Hidden Agendas (Tom Clancy's Net Force, No. 2)",
#  'Hidden Jewel (Landry)',
#  'Hidden Riches',
#  'Hide &amp; Seek',
#  'Hideaway',
#  'Hiding in the Shadows (Shadows Trilogy (Paperback))',
#  'High Fidelity',
#  'High Five (A Stephanie Plum Novel)',
#  'High Maintenance',
#  'High Tide',
#  'Hill Towns',
#  'Hiroshima',
#  "Hitchhikers's Guide to the Galaxy",
#  'Holding the Dream (Dream Trilogy)',
#  'Holes (Yearling Newbery)',
#  'Holidays on Ice : Stories',
#  'Home Song',
#  'Homeport',
#  'Honor Among Thieves',
#  'Hornet Flight',
#  "Hornet's Nest",
#  'Horse Whisperer',
#  'Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#  'House Atreides (Dune: House Trilogy, Book 1)',
#  'House of Leaves',
#  'House of Sand and Fog',
#  'How Stella Got Her Groove Back',
#  'How To Win Friends And Influence People',
#  'How the Garcia Girls Lost Their Accents (Plume Contemporary Fiction)',
#  'How to Be Good',
#  'How to Make an American Quilt',
#  'Hunting Badger (Joe Leaphorn/Jim Chee Novels)',
#  'Hunting Season (Anna Pigeon Novels (Paperback))',
#  'I Capture the Castle',
#  "I Don't Know How She Does It",
#  "I Don't Know How She Does It: The Life of Kate Reddy, Working Mother",
#  'I Is for Innocent',
#  'I Know This Much Is True',
#  "I Know This Much Is True (Oprah's Book Club)",
#  'I Know Why the Caged Bird Sings',
#  "I'll Be Seeing You",
#  "I'll Take Manhattan",
#  "I'm a Stranger Here Myself: Notes on Returning to America After 20 Years Away",
#  'I, Robot',
#  "Ice Bound: A Doctor's Incredible Battle for Survival at the South Pole",
#  'Icebound',
#  'Icy Sparks',
#  'Idoru',
#  "If I'd Killed Him When I Met Him (Elizabeth MacPherson Novels (Paperback))",
#  'If Only It Were True',
#  'Ill Wind (Anna Pigeon Mysteries (Paperback))',
#  'Illuminati.',
#  'Illusions',
#  'Illusions: The Adventures of a Reluctant Messiah',
#  'Imitation in Death (Eve Dallas Mysteries (Paperback))',
#  'Impulse',
#  'In Cold Blood (Vintage International)',
#  'In Her Shoes : A Novel',
#  'In Pursuit of the Proper Sinner',
#  "In the Kitchen With Rosie: Oprah's Favorite Recipes",
#  'In the Presence of the Enemy',
#  'Inca Gold (Clive Cussler)',
#  'Inner Harbor (Quinn Brothers (Paperback))',
#  'Insomnia',
#  'Intensity',
#  'Interest of Justice',
#  'Interpreter of Maladies',
#  'Interview with the Vampire',
#  'Into Thin Air : A Personal Account of the Mount Everest Disaster',
#  'Into Thin Air : A Personal Account of the Mt. Everest Disaster',
#  'Into the Wild',
#  'Invasion',
#  'Invisible Monsters',
#  'Irish Hearts',
#  'Irish Rebel (Special Edition, 1328)',
#  'Irresistible Forces',
#  'Ishmael: An Adventure of the Mind and Spirit',
#  'Island of the Blue Dolphins',
#  'Island of the Blue Dolphins (Laurel Leaf Books)',
#  'Isle of Dogs',
#  'It',
#  'It Was on Fire When I Lay Down on It',
#  "It's Always Something",
#  "It's My F---ing Birthday : A Novel",
#  "It's Not About the Bike: My Journey Back to Life",
#  'J Is for Judgment',
#  'Jack &amp; Jill (Alex Cross Novels)',
#  'Jackdaws',
#  'James and the Giant Peach',
#  'Jane Eyre (Bantam Classics)',
#  'Jazz (Plume Contemporary Fiction)',
#  'Jemima J',
#  'Jemima J: A Novel About Ugly Ducklings and Swans',
#  'Jennifer Government : A Novel',
#  'Jewel',
#  "Jewel (Oprah's Book Club)",
#  'Jewels',
#  'Jewels of the Sun (Irish Trilogy)',
#  'Jitterbug Perfume',
#  'Job: A Comedy of Justice',
#  'Jonathan Livingston Seagull',
#  'Journey',
#  'Judgment in Death',
#  'Julie and Romeo: A Novel',
#  'Julie of the Wolves (Julie of the Wolves)',
#  "Jupiter's Bones : A Peter Decker/Rina Lazarus Novel (Peter Decker &amp; Rina Lazarus Novels (Paperback))",
#  'Jurassic Park',
#  'K Is for Killer (Kinsey Millhone Mysteries (Paperback))',
#  'Kaleidoscope',
#  'Key of Knowledge (Key Trilogy (Paperback))',
#  'Key of Light (Key Trilogy (Paperback))',
#  'Key of Valor (Roberts, Nora. Key Trilogy, 3.)',
#  'Kill and Tell',
#  'Killer Pancake',
#  'Killing Time',
#  'Killjoy',
#  'Kiss of the Bees: A Novel of Suspense',
#  'Kiss the Girls',
#  'Kitchen',
#  'Kitchen Confidential: Adventures in the Culinary Underbelly',
#  'Koko',
#  "Kushiel's Dart",
#  'L Is for Lawless',
#  'L Is for Lawless (Kinsey Millhone Mysteries)',
#  'LONESOME DOVE',
#  'Ladder of Years',
#  'Lake News',
#  'Lake Wobegon Days',
#  'Lake Wobegon days',
#  "Lamb : The Gospel According to Biff, Christ's Childhood Pal",
#  'Lasher',
#  'Lasher: Lives of the Mayfair Witches (Lives of the Mayfair Witches)',
#  'Last Chance Saloon',
#  "Last Dance, Last Chance (Ann Rule's Crime Files)",
#  'Last Man Standing',
#  'Le Divorce (William Abrahams Book)',
#  'Leap of Faith',
#  "Left Behind: A Novel of the Earth's Last Days (Left Behind #1)",
#  "Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)",
#  'Legacy of Silence',
#  'Legal Tender',
#  'Legend',
#  'Less Of A Stranger (Silhouette Single Title)',
#  'Let Me Call You Sweetheart',
#  'Letters from a Nut',
#  'Lie Down With Lions',
#  'Lies and the Lying Liars Who Tell Them: A Fair and Balanced Look at the Right',
#  'Life Strategies: Doing What Works, Doing What Matters',
#  'Life Support',
#  'Life of Pi',
#  "Life's Little Instruction Book (Life's Little Instruction Books (Paperback))",
#  'Life,the Universe and Everything',
#  'Lightning',
#  'Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies',
#  'Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies',
#  'Like Water for Chocolate: A Novel in Monthly Installments, With Recipes, Romances, and Home Remedies',
#  'Lion, the Witch and the Wardrobe',
#  'Little Altars Everywhere',
#  'Little Altars Everywhere: A Novel',
#  'Little House in the Big Woods',
#  'Little House on the Prairie',
#  'Living Dead in Dallas (Southern Vampire Mysteries)',
#  'Lolita (Vintage International)',
#  'London : The Novel',
#  'London Transports',
#  'Lone Eagle',
#  'Lonesome Dove',
#  'Long After Midnight',
#  'Long Dark Tea Time of the Soul',
#  'Long Time No See',
#  'Looking Back',
#  'Lord of the Flies',
#  'Los Alamos: A Novel',
#  'Lost Light',
#  'Lost Souls',
#  'Lost in a Good Book: A Thursday Next Novel',
#  'Love in the Time of Cholera (Penguin Great Books of the 20th Century)',
#  'Loves Music, Loves to Dance',
#  'Low Country',
#  'Lucky',
#  'Lucky : A Memoir',
#  'Lucky Man: A Memoir',
#  'Lucky You',
#  'Lucy Sullivan Is Getting Married',
#  'Lullaby: A Novel',
#  'M Is for Malice',
#  'M Is for Malice (Kinsey Millhone Mysteries (Hardcover))',
#  'MOONLIGHT BECOMES YOU',
#  'Macgregor Brides (Macgregors)',
#  'Macgregor Grooms (Macgregors)',
#  'Magic Kingdom for Sale - Sold! (Magic Kingdom of Landover)',
#  'Make the Connection: Ten Steps to a Better Body and a Better Life',
#  'Malice',
#  'Mama Makes Up Her Mind: And Other Dangers of Southern Living',
#  'Man From St Petersburg',
#  'Man and Boy: A Novel',
#  'Manhattan Hunt Club',
#  'Master of the Game',
#  'Matilda',
#  "McNally's Secret (Archy McNally Novels (Paperback))",
#  'Me Talk Pretty One Day',
#  'Melody (Logan)',
#  'Memnoch the Devil (Vampire Chronicles, No 5)',
#  'Memnoch the Devil : The Vampire Chronicles (Vampire Chronicles)',
#  'Memoirs of a Geisha',
#  'Memoirs of a Geisha Uk',
#  'Memories of Midnight',
#  'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships',
#  'Mercy',
#  'Merrick (Vampire Chronicles)',
#  'Merrick (Vampire/Witches Chronicles)',
#  'Message from Nam',
#  'Message in a Bottle',
#  'Middle of Nowhere',
#  'Middlesex: A Novel',
#  'Midnight',
#  'Midnight Bayou',
#  'Midnight Voices',
#  'Midnight Whispers (Cutler)',
#  'Midnight in the Garden of Good and Evil',
#  'Midnight in the Garden of Good and Evil: A Savannah Story',
#  "Midnight's Children",
#  'Midwives: A Novel',
#  'Milk and Honey (Peter Decker/Rina Lazarus Novels)',
#  'Milkrun',
#  'Mind Prey',
#  'Mindbend',
#  'Miracle Cure',
#  'Mirror Image',
#  'Misery',
#  'Miss Julia Speaks Her Mind : A Novel',
#  'Missing Joseph',
#  'Mistaken Identity',
#  'Mitigating Circumstances',
#  'Mixed Blessings',
#  'Moment of Truth',
#  'Monster : A Novel (Alex Delaware Novels (Paperback))',
#  'Monster Blood (Goosebumps, No 3)',
#  'Montana',
#  'Montana Sky',
#  'Moo',
#  'Moon Music (Peter Decker &amp; Rina Lazarus Novels (Paperback))',
#  'Moonlight Becomes You',
#  'Morality for Beautiful Girls (No.1 Ladies Detective Agency)',
#  'Moreta: Dragonlady of Pern',
#  'Morning Glory',
#  'Morning, Noon &amp; Night',
#  'Mortal Fear',
#  'Mortal Prey',
#  'Mother of Pearl',
#  "Mother of Pearl (Oprah's Book Club (Paperback))",
#  'Move to Strike',
#  'Moving Target',
#  'Mr. Maybe',
#  'Mr. Murder',
#  'Mr. Perfect',
#  'Mrs Dalloway',
#  'Music in the Night (Logan)',
#  'Must Love Dogs',
#  'Must Love Dogs: A Novel',
#  'Mutant Message Down Under',
#  'Mutation',
#  'My Dream of You',
#  'My Gal Sunday',
#  'My Point - And I Do Have One',
#  'My Point...And I Do Have One',
#  'Mystic River',
#  'MÃ?Â¶rder ohne Gesicht.',
#  'N Is for Noose',
#  'N Is for Noose (Kinsey Millhone Mysteries (Hardcover))',
#  'Naked',
#  'Naked Prey',
#  'Naked in Death',
#  'Name Dropping : What If Two Very Different Women Had The Same Exact Name?',
#  'Name of the Rose-Nla',
#  'Narcissus in Chains (Anita Blake Vampire Hunter (Paperback))',
#  'Native Tongue',
#  'Natural Causes',
#  'Neanderthal: A Novel',
#  'Needful Things',
#  'Needful Things: The Last Castle Rock Story',
#  'Nerd in Shining Armor',
#  'Net Force',
#  'Neuromancer (Remembering Tomorrow)',
#  'Never Change',
#  'Neverwhere',
#  'Nickel and Dimed: On (Not) Getting By in America',
#  'Nicolae: The Rise of Antichrist (Left Behind No. 3)',
#  'Night',
#  'Night Chills',
#  "Night Moves (Tom Clancy's Net Force, No. 3)",
#  'Night Prey',
#  'Night Shield (Intimate Moments, 1027)',
#  'Night Shift',
#  'Night Sins',
#  'Night Whispers',
#  'Night over Water',
#  'Nightmares &amp; Dreamscapes',
#  'Nights in Rodanthe',
#  'Nightshade',
#  'Nine Stories',
#  'No Greater Love',
#  'No One to Trust',
#  'No Safe Place',
#  'No Second  Chance',
#  'Nora, Nora: A Novel',
#  'Northern Lights (His Dark Materials S.)',
#  'Not Without My Daughter',
#  'Notes From a Small Planet',
#  'Notes from a Small Island',
#  'Nothing Lasts Forever',
#  'Now You See Her',
#  'Now You See Me',
#  'Now and Forever',
#  'Number the Stars (Yearling Newbery)',
#  'Numbered Account',
#  'OLD MAN AND THE SEA',
#  'ONE DAY MY SOUL JUST OPENED UP : 40 DAYS AND 40 NIGHTS TOWARD SPIRITUAL STRENGTH AND PERSONAL GROWTH',
#  'Obasan',
#  'Object Lessons',
#  'October Sky: A Memoir',
#  'Odd Thomas',
#  'Of Mice and Men (Penguin Great Books of the 20th Century)',
#  'Oldest Living Confederate Widow Tells All',
#  'On Mystic Lake',
#  'On Writing',
#  'On a Pale Horse (Incarnations of Immortality, Bk. 1)',
#  'On the Road',
#  'On the Road (Penguin 20th Century Classics)',
#  'On the Street Where You Live',
#  'On the Street Where You Live : A Novel',
#  'Once a Thief',
#  'Once in a Lifetime',
#  'Once upon a More Enlightened Time: More Politically Correct Bedtime Stories',
#  'One',
#  'One Door Away from Heaven',
#  "One Flew Over the Cuckoo's Nest",
#  'One Hundred Years of Solitude',
#  "One Hundred Years of Solitude (Oprah's Book Club)",
#  'One Thousand White Women : The Journals of May Dodd: A Novel',
#  'One True Thing',
#  'One for the Money (A Stephanie Plum Novel)',
#  'One for the Money (Stephanie Plum Novels (Paperback))',
#  'Open House',
#  "Open House (Oprah's Book Club (Paperback))",
#  'Open Season',
#  'Orchid Beach (Holly Barker Novels (Paperback))',
#  'Orchid Blues (Holly Barker Novels (Paperback))',
#  'Oryx and Crake',
#  'Out of Africa ; and, Shadows on the grass',
#  'Out of the Shadows (Shadows Trilogy (Paperback))',
#  'Out to Canaan (The Mitford Years)',
#  'Outbreak',
#  'Outer Banks',
#  'Outlander',
#  ...]

# %%
# Function to get the Index of the Book
def get_index(req):
  count=0
  for i in books_list:
    count+=1
    alpha=i.lower()
    
    if alpha==req:
      return (count-1)
    else:
      continue

# %%
app = Flask(__name__,template_folder='templates/templates')
model = pickle.load(open('model/model_recom.pkl', 'rb'))
run_with_ngrok(app)

@app.route('/')
def home():
    return render_template('book_index.html')

@app.route('/predict',methods=['POST'])
def predict():
  if request.method == 'POST':
    message = str(request.form['message'])
    inp=str(message)
    ind=get_index(message)
    if bool(ind)== True:
      distances, indices = model.kneighbors(data_pivot.iloc[ind,:].values.reshape(1, -1), n_neighbors = 6)
      Listofbooks=[]
      for i in range(0, len(distances.flatten())):
        Listofbooks.append(data_pivot.index[indices.flatten()[i]])
      return render_template('book_index.html',prediction_text = 'Recommended Books for: {}'.format(Listofbooks[0]),
                             prediction_text1 = '1]  {}'.format(Listofbooks[1]),
                             prediction_text2 = '2]  {}'.format(Listofbooks[2]),
                             prediction_text3 = '3]  {}'.format(Listofbooks[3]),
                             prediction_text4 = '4]  {}'.format(Listofbooks[4]),
                             prediction_text5 = '5]  {}'.format(Listofbooks[5]))
    elif bool(ind)== False:
      return render_template('book_index.html',prediction_text = 'Sorry!! We Do not have that book in our Dataset')




if __name__ == "__main__":
  app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "/Users/kishore/opt/anaconda3/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Users/kishore/opt/anaconda3/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/kishore/opt/anaconda3/lib/python3.9/site-packages/flask_ngrok2.py", line 92, in start_ngrok
#     ngrok_address = _run_ngrok(port, auth_token)
#   File "/Users/kishore/opt/anaconda3/lib/python3.9/site-packages/flask_ngrok2.py", line 60, in _run_ngrok
#     tunnel_url = j["tunnels"][0]["public_url"]  # Do the parsing of the get
# IndexError: list index out of range
